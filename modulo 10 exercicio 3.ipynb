# %% [markdown]
# # Módulo 10 tarefa 03
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

previsao_de_renda = pd.read_csv('/content/previsao_de_renda.csv', index_col=[0]).drop('index', axis=1)
previsao_de_renda
# Out:
#          data_ref sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0      2015-01-01    F             False             True           1
# 1      2015-01-01    M              True             True           0
# 2      2015-01-01    M              True             True           2
# 3      2015-01-01    F              True            False           0
# 4      2015-01-01    M             False            False           0
# ...           ...  ...               ...              ...         ...
# 14995  2016-03-01    M              True             True           1
# 14996  2016-03-01    M              True             True           1
# 14997  2016-03-01    F              True             True           0
# 14998  2016-03-01    F             False             True           0
# 14999  2016-03-01    F              True             True           0
#
#              tipo_renda           educacao estado_civil tipo_residencia  \
# ...

# %% [markdown]
# 1) Construa um gráfico de barras para avaliar a distribuição das variáveis qualitativas no tempo. Você acha que houve alguma alteração importante a ser investigada?

# %%
previsao_de_renda['data_ref'] = pd.to_datetime(previsao_de_renda['data_ref']).dt.strftime("%m-%Y")

# %%
previsao_de_renda
# Out:
#       data_ref sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  \
# 0      01-2015    F             False             True           1
# 1      01-2015    M              True             True           0
# 2      01-2015    M              True             True           2
# 3      01-2015    F              True            False           0
# 4      01-2015    M             False            False           0
# ...        ...  ...               ...              ...         ...
# 14995  03-2016    M              True             True           1
# 14996  03-2016    M              True             True           1
# 14997  03-2016    F              True             True           0
# 14998  03-2016    F             False             True           0
# 14999  03-2016    F              True             True           0
#
#              tipo_renda           educacao estado_civil tipo_residencia  \
# 0           Assalariado         Secundário       Casado            Casa
# ...

# %%
ax = sns.countplot(x='data_ref', hue='sexo', data=previsao_de_renda)
plt.xticks(rotation=90)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# 2) Para cada variável qualitativa, construa um gráfico mostrando as médias de cada nível da variável no tempo e avalie a estabilidade. Houve alguma alteração importante? Você acha que se pode utilizar essas variáveis em uma modelagem?

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(20,10))

sns.pointplot(x='data_ref', y='renda', hue='sexo', data=previsao_de_renda, ax=ax[0][0])
sns.pointplot(x='data_ref', y='posse_de_veiculo', hue='sexo', data=previsao_de_renda, ax=ax[0][1])
sns.pointplot(x='data_ref', y='posse_de_imovel', hue='sexo', data=previsao_de_renda, ax=ax[1][1])
sns.pointplot(x='data_ref', y='tempo_emprego', hue='sexo', data=previsao_de_renda, ax=ax[1][0])
plt.xticks(rotation=90)

plt.show()
